# %%
import pandas as pd
import numpy as np

# %%
df_pred = pd.read_csv('../data/processed/predicted_synthetic_compounds.csv')

# %%
abo3_all = df_pred[(df_pred['type']=='ABO3') & (df_pred['Insulator'] == 1)]

# %%
df_ABO3 = df_pred[(df_pred['type'] == 'ABO3') & (df_pred['stable'] == 1) & (df_pred['Insulator'] == 1)]
df_A2B1B2O6 = df_pred[(df_pred['type'] == 'A2B1B2O6') & (df_pred['stable'] == 1) & (df_pred['Insulator'] == 1)]
df_A1A2B2O6 = df_pred[(df_pred['type'] == 'A1A2B2O6') & (df_pred['stable'] == 1) & (df_pred['Insulator'] == 1)]
df_A1A2B1B2O6 = df_pred[(df_pred['type'] == 'A1A2B1B2O6') & (df_pred['stable'] == 1) & (df_pred['Insulator'] == 1)]

# %%
print(len(df_ABO3), len(df_A2B1B2O6), len(df_A1A2B2O6), len(df_A1A2B1B2O6))
# Out:
# 11 1908 111 78084

# %%
ionic_radii_database = {
    "Mn": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.66},
        {"oxidation_num": 2, "corr": 5, "radi": 0.75},
        {"oxidation_num": 2, "corr": 6, "radi": 0.67},
        {"oxidation_num": 2, "corr": 6, "radi": 0.83},
        {"oxidation_num": 2, "corr": 7, "radi": 0.90},
        {"oxidation_num": 2, "corr": 8, "radi": 0.96},
        {"oxidation_num": 3, "corr": 5, "radi": 0.58},
        {"oxidation_num": 3, "corr": 6, "radi": 0.645},
        {"oxidation_num": 3, "corr": 6, "radi": 0.58},
        {"oxidation_num": 4, "corr": 4, "radi": 0.39},
        {"oxidation_num": 4, "corr": 6, "radi": 0.53},
        {"oxidation_num": 5, "corr": 4, "radi": 0.33},
        {"oxidation_num": 6, "corr": 4, "radi": 0.255},
        {"oxidation_num": 7, "corr": 4, "radi": 0.25},
        {"oxidation_num": 7, "corr": 6, "radi": 0.46}
    ],
    "Pm": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.970},
        {"oxidation_num": 3, "corr": 8, "radi": 1.093},
        {"oxidation_num": 3, "corr": 9, "radi": 1.144},
        {"oxidation_num": 2, "corr": 6, "radi": 1.154}
    ],
    "Fe": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.63},
        {"oxidation_num": 2, "corr": 6, "radi": 0.61},
        {"oxidation_num": 2, "corr": 6, "radi": 0.78},
        {"oxidation_num": 2, "corr": 8, "radi": 0.92},
        {"oxidation_num": 3, "corr": 4, "radi": 0.49},
        {"oxidation_num": 3, "corr": 5, "radi": 0.58},
        {"oxidation_num": 3, "corr": 6, "radi": 0.55},
        {"oxidation_num": 3, "corr": 6, "radi": 0.645},
        {"oxidation_num": 3, "corr": 8, "radi": 0.78},
        {"oxidation_num": 4, "corr": 6, "radi": 0.585},
        {"oxidation_num": 6, "corr": 4, "radi": 0.25}
    ],
    "Tl": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.50},
        {"oxidation_num": 1, "corr": 8, "radi": 1.59},
        {"oxidation_num": 1, "corr": 12, "radi": 1.70},
        {"oxidation_num": 3, "corr": 4, "radi": 0.75},
        {"oxidation_num": 3, "corr": 6, "radi": 0.885},
        {"oxidation_num": 3, "corr": 8, "radi": 0.98}
    ],
    "Dy": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.07},
        {"oxidation_num": 2, "corr": 7, "radi": 1.13},
        {"oxidation_num": 2, "corr": 8, "radi": 1.19},
        {"oxidation_num": 3, "corr": 6, "radi": 0.912},
        {"oxidation_num": 3, "corr": 7, "radi": 0.97},
        {"oxidation_num": 3, "corr": 8, "radi": 1.027},
        {"oxidation_num": 3, "corr": 9, "radi": 1.083},
        {"oxidation_num": 4, "corr": 9, "radi": 0.69}
    ],
    "Nd": [
        {"oxidation_num": 2, "corr": 8, "radi": 1.29},
        {"oxidation_num": 2, "corr": 9, "radi": 1.35},
        {"oxidation_num": 3, "corr": 6, "radi": 0.983},
        {"oxidation_num": 3, "corr": 8, "radi": 1.109},
        {"oxidation_num": 3, "corr": 9, "radi": 1.163},
        {"oxidation_num": 3, "corr": 12, "radi": 1.27}
    ],
    "Ce": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.21},
        {"oxidation_num": 3, "corr": 6, "radi": 1.01},
        {"oxidation_num": 3, "corr": 7, "radi": 1.07},
        {"oxidation_num": 3, "corr": 8, "radi": 1.143},
        {"oxidation_num": 3, "corr": 9, "radi": 1.196},
        {"oxidation_num": 3, "corr": 10, "radi": 1.25},
        {"oxidation_num": 3, "corr": 12, "radi": 1.34},
        {"oxidation_num": 4, "corr": 6, "radi": 0.87},
        {"oxidation_num": 4, "corr": 8, "radi": 0.97},
        {"oxidation_num": 4, "corr": 10, "radi": 1.07},
        {"oxidation_num": 4, "corr": 12, "radi": 1.14}
    ],
    "Au": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.37},
        {"oxidation_num": 3, "corr": 6, "radi": 0.85},
        {"oxidation_num": 5, "corr": 6, "radi": 0.57}
    ],
    "Cu": [
        {"oxidation_num": 1, "corr": 2, "radi": 0.46},
        {"oxidation_num": 1, "corr": 4, "radi": 0.60},
        {"oxidation_num": 1, "corr": 6, "radi": 0.77},
        {"oxidation_num": 2, "corr": 4, "radi": 0.57},
        {"oxidation_num": 2, "corr": 5, "radi": 0.65},
        {"oxidation_num": 2, "corr": 6, "radi": 0.73},
        {"oxidation_num": 3, "corr": 6, "radi": 0.54}
    ],
    "Eu": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.17},
        {"oxidation_num": 2, "corr": 7, "radi": 1.20},
        {"oxidation_num": 2, "corr": 8, "radi": 1.25},
        {"oxidation_num": 2, "corr": 9, "radi": 1.30},
        {"oxidation_num": 2, "corr": 10, "radi": 1.35},
        {"oxidation_num": 3, "corr": 6, "radi": 0.947},
        {"oxidation_num": 3, "corr": 7, "radi": 1.01},
        {"oxidation_num": 3, "corr": 8, "radi": 1.066},
        {"oxidation_num": 3, "corr": 9, "radi": 1.12}
    ],
    "Tm": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.03},
        {"oxidation_num": 2, "corr": 7, "radi": 1.09},
        {"oxidation_num": 3, "corr": 6, "radi": 0.880},
        {"oxidation_num": 3, "corr": 8, "radi": 0.994},
        {"oxidation_num": 3, "corr": 9, "radi": 1.052},
        {"oxidation_num": 4, "corr": 9, "radi": 0.700}
    ],
    "Pr": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.990},
        {"oxidation_num": 2, "corr": 6, "radi": 1.190},
        {"oxidation_num": 3, "corr": 8, "radi": 1.126},
        {"oxidation_num": 3, "corr": 9, "radi": 1.179},
        {"oxidation_num": 4, "corr": 6, "radi": 0.850},
        {"oxidation_num": 4, "corr": 8, "radi": 0.960},
        {"oxidation_num": 5, "corr": 8, "radi": 0.760}
    ],
    "Er": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.20},
        {"oxidation_num": 3, "corr": 6, "radi": 0.890},
        {"oxidation_num": 3, "corr": 7, "radi": 0.945},
        {"oxidation_num": 3, "corr": 8, "radi": 1.004},
        {"oxidation_num": 3, "corr": 9, "radi": 1.062}
    ],
    "Lu": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.861},
        {"oxidation_num": 3, "corr": 8, "radi": 0.977},
        {"oxidation_num": 3, "corr": 9, "radi": 1.032}
    ],
    "Cd": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.78},
        {"oxidation_num": 2, "corr": 5, "radi": 0.87},
        {"oxidation_num": 2, "corr": 6, "radi": 0.95},
        {"oxidation_num": 2, "corr": 7, "radi": 1.03},
        {"oxidation_num": 2, "corr": 8, "radi": 1.10},
        {"oxidation_num": 2, "corr": 12, "radi": 1.31}
    ],
    "Cr": [
        {"oxidation_num": 2, "corr": 6, "radi": 0.80},
        {"oxidation_num": 2, "corr": 6, "radi": 0.73},
        {"oxidation_num": 3, "corr": 6, "radi": 0.615},
        {"oxidation_num": 4, "corr": 4, "radi": 0.41},
        {"oxidation_num": 4, "corr": 6, "radi": 0.55},
        {"oxidation_num": 5, "corr": 4, "radi": 0.345},
        {"oxidation_num": 5, "corr": 6, "radi": 0.49},
        {"oxidation_num": 5, "corr": 8, "radi": 0.57},
        {"oxidation_num": 6, "corr": 4, "radi": 0.26},
        {"oxidation_num": 6, "corr": 6, "radi": 0.44}
    ],
    "Tb": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.20},
        {"oxidation_num": 3, "corr": 6, "radi": 0.923},
        {"oxidation_num": 3, "corr": 7, "radi": 0.98},
        {"oxidation_num": 3, "corr": 8, "radi": 1.04},
        {"oxidation_num": 3, "corr": 9, "radi": 1.095},
        {"oxidation_num": 4, "corr": 6, "radi": 0.76},
        {"oxidation_num": 4, "corr": 8, "radi": 0.88},
        {"oxidation_num": 5, "corr": 8, "radi": 0.62}
    ],
    "Y": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.100},
        {"oxidation_num": 3, "corr": 6, "radi": 0.900},
        {"oxidation_num": 3, "corr": 7, "radi": 0.96},
        {"oxidation_num": 3, "corr": 8, "radi": 1.019},
        {"oxidation_num": 3, "corr": 9, "radi": 1.075},
        {"oxidation_num": 4, "corr": 9, "radi": 0.800}
    ],
    "Sm": [
        {"oxidation_num": 2, "corr": 7, "radi": 1.22},
        {"oxidation_num": 2, "corr": 8, "radi": 1.27},
        {"oxidation_num": 2, "corr": 9, "radi": 1.32},
        {"oxidation_num": 3, "corr": 6, "radi": 0.958},
        {"oxidation_num": 3, "corr": 7, "radi": 1.02},
        {"oxidation_num": 3, "corr": 8, "radi": 1.079},
        {"oxidation_num": 3, "corr": 9, "radi": 1.132},
        {"oxidation_num": 3, "corr": 12, "radi": 1.24}
    ],
    "Hg": [
        {"oxidation_num": 1, "corr": 3, "radi": 0.97},
        {"oxidation_num": 1, "corr": 6, "radi": 1.19},
        {"oxidation_num": 2, "corr": 2, "radi": 0.69},
        {"oxidation_num": 2, "corr": 4, "radi": 0.96},
        {"oxidation_num": 2, "corr": 6, "radi": 1.02},
        {"oxidation_num": 2, "corr": 8, "radi": 1.14}
    ],
    "La": [
        {"oxidation_num": 3, "corr": 6, "radi": 1.032},
        {"oxidation_num": 3, "corr": 7, "radi": 1.10},
        {"oxidation_num": 3, "corr": 8, "radi": 1.16},
        {"oxidation_num": 3, "corr": 9, "radi": 1.216},
        {"oxidation_num": 3, "corr": 10, "radi": 1.27},
        {"oxidation_num": 3, "corr": 12, "radi": 1.36}
    ],
    "Ho": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.201},
        {"oxidation_num": 3, "corr": 6, "radi": 0.901},
        {"oxidation_num": 3, "corr": 8, "radi": 1.015},
        {"oxidation_num": 3, "corr": 9, "radi": 1.072},
        {"oxidation_num": 3, "corr": 10, "radi": 1.12}
    ],
    "Ag": [
        {"oxidation_num": 1, "corr": 2, "radi": 0.67},
        {"oxidation_num": 1, "corr": 4, "radi": 1.00},

        {"oxidation_num": 1, "corr": 5, "radi": 1.09},
        {"oxidation_num": 1, "corr": 6, "radi": 1.15},
        {"oxidation_num": 1, "corr": 7, "radi": 1.22},
        {"oxidation_num": 1, "corr": 8, "radi": 1.28},
        {"oxidation_num": 2, "corr": 6, "radi": 0.94},
        {"oxidation_num": 3, "corr": 6, "radi": 0.75}
    ],
    "Sr": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.18},
        {"oxidation_num": 2, "corr": 7, "radi": 1.21},
        {"oxidation_num": 2, "corr": 8, "radi": 1.26},
        {"oxidation_num": 2, "corr": 9, "radi": 1.31},
        {"oxidation_num": 2, "corr": 10, "radi": 1.36},
        {"oxidation_num": 2, "corr": 12, "radi": 1.44}
    ],
    "Ca": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.00},
        {"oxidation_num": 2, "corr": 7, "radi": 1.06},
        {"oxidation_num": 2, "corr": 8, "radi": 1.12},
        {"oxidation_num": 2, "corr": 9, "radi": 1.18},
        {"oxidation_num": 2, "corr": 10, "radi": 1.23},
        {"oxidation_num": 2, "corr": 12, "radi": 1.34}
    ],
    "Gd": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.2138},
        {"oxidation_num": 3, "corr": 6, "radi": 0.938},
        {"oxidation_num": 3, "corr": 7, "radi": 1.00},
        {"oxidation_num": 3, "corr": 8, "radi": 1.053},
        {"oxidation_num": 3, "corr": 9, "radi": 1.107}
    ],
    "Ti": [
        {"oxidation_num": 2, "corr": 6, "radi": 0.86},
        {"oxidation_num": 3, "corr": 6, "radi": 0.67},
        {"oxidation_num": 4, "corr": 4, "radi": 0.42},
        {"oxidation_num": 4, "corr": 5, "radi": 0.51},
        {"oxidation_num": 4, "corr": 6, "radi": 0.605},
        {"oxidation_num": 4, "corr": 8, "radi": 0.74}
    ],
    "Co": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.58},
        {"oxidation_num": 2, "corr": 5, "radi": 0.67},
        {"oxidation_num": 2, "corr": 6, "radi": 0.65},
        {"oxidation_num": 2, "corr": 6, "radi": 0.745},
        {"oxidation_num": 2, "corr": 8, "radi": 0.90},
        {"oxidation_num": 3, "corr": 6, "radi": 0.545},
        {"oxidation_num": 3, "corr": 6, "radi": 0.61},
        {"oxidation_num": 4, "corr": 4, "radi": 0.40},
        {"oxidation_num": 4, "corr": 6, "radi": 0.53}
    ],
    "In": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.32},
        {"oxidation_num": 3, "corr": 4, "radi": 0.62},
        {"oxidation_num": 3, "corr": 6, "radi": 0.80},
        {"oxidation_num": 3, "corr": 8, "radi": 0.92}
    ],
    "Bi": [
        {"oxidation_num": 3, "corr": 5, "radi": 0.96},
        {"oxidation_num": 3, "corr": 6, "radi": 1.03},
        {"oxidation_num": 3, "corr": 8, "radi": 1.17},
        {"oxidation_num": 5, "corr": 6, "radi": 0.76}
    ],
    "Zn": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.60},
        {"oxidation_num": 2, "corr": 5, "radi": 0.68},
        {"oxidation_num": 2, "corr": 6, "radi": 0.74},
        {"oxidation_num": 2, "corr": 8, "radi": 0.90}
    ],
    "Tc": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.99},
        {"oxidation_num": 4, "corr": 6, "radi": 0.645},
        {"oxidation_num": 5, "corr": 6, "radi": 0.60},
        {"oxidation_num": 6, "corr": 6, "radi": 0.59},
        {"oxidation_num": 7, "corr": 4, "radi": 0.37},
        {"oxidation_num": 7, "corr": 6, "radi": 0.56}
    ],
    "Sc": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.745},
        {"oxidation_num": 3, "corr": 8, "radi": 0.87}
    ],
    "K": [
        {"oxidation_num": 1, "corr": 4, "radi": 1.37},
        {"oxidation_num": 1, "corr": 6, "radi": 1.38},
        {"oxidation_num": 1, "corr": 7, "radi": 1.46},
        {"oxidation_num": 1, "corr": 8, "radi": 1.51},
        {"oxidation_num": 1, "corr": 9, "radi": 1.55},
        {"oxidation_num": 1, "corr": 10, "radi": 1.59},
        {"oxidation_num": 1, "corr": 12, "radi": 1.64},
        {"oxidation_num": 3, "corr": 12, "radi": 0.64}
    ],
    "Li": [
        {"oxidation_num": 1, "corr": 4, "radi": 0.59},
        {"oxidation_num": 1, "corr": 6, "radi": 0.76},
        {"oxidation_num": 1, "corr": 8, "radi": 0.92},
        {"oxidation_num": 3, "corr": 8, "radi": 0.52}
    ],
    "Pd": [
        {"oxidation_num": 1, "corr": 2, "radi": 0.59},
        {"oxidation_num": 2, "corr": 6, "radi": 0.86},
        {"oxidation_num": 3, "corr": 6, "radi": 0.76},
        {"oxidation_num": 4, "corr": 6, "radi": 0.615}
    ],
    "Pb": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.19},
        {"oxidation_num": 2, "corr": 7, "radi": 1.23},
        {"oxidation_num": 2, "corr": 8, "radi": 1.29},
        {"oxidation_num": 2, "corr": 9, "radi": 1.35},
        {"oxidation_num": 2, "corr": 10, "radi": 1.40},
        {"oxidation_num": 2, "corr": 11, "radi": 1.45},
        {"oxidation_num": 2, "corr": 12, "radi": 1.49},
        {"oxidation_num": 4, "corr": 4, "radi": 0.65},
        {"oxidation_num": 4, "corr": 5, "radi": 0.73},
        {"oxidation_num": 4, "corr": 6, "radi": 0.775},
        {"oxidation_num": 4, "corr": 8, "radi": 0.94}
    ],
    "Ba": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.35},
        {"oxidation_num": 2, "corr": 7, "radi": 1.38},
        {"oxidation_num": 2, "corr": 8, "radi": 1.42},
        {"oxidation_num": 2, "corr": 9, "radi": 1.47},
        {"oxidation_num": 2, "corr": 10, "radi": 1.52},
        {"oxidation_num": 2, "corr": 11, "radi": 1.57},
        {"oxidation_num": 2, "corr": 12, "radi": 1.61}
    ],
    "Sb": [
        {"oxidation_num": 3, "corr": 5, "radi": 0.80},
        {"oxidation_num": 3, "corr": 6, "radi": 0.76},
        {"oxidation_num": 5, "corr": 6, "radi": 0.60}
    ],
    "Cs": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.67},
        {"oxidation_num": 1, "corr": 8, "radi": 1.74},
        {"oxidation_num": 1, "corr": 9, "radi": 1.78},
        {"oxidation_num": 1, "corr": 10, "radi": 1.81},
        {"oxidation_num": 1, "corr": 11, "radi": 1.85},
        {"oxidation_num": 1, "corr": 12, "radi": 1.88}
    ],
    "Mo": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.69},
        {"oxidation_num": 4, "corr": 6, "radi": 0.65},
        {"oxidation_num": 5, "corr": 4, "radi": 0.46},
        {"oxidation_num": 5, "corr": 6, "radi": 0.61},
        {"oxidation_num": 6, "corr": 4, "radi": 0.41},
        {"oxidation_num": 6, "corr": 5, "radi": 0.50},
        {"oxidation_num": 6, "corr": 6, "radi": 0.59},
        {"oxidation_num": 6, "corr": 7, "radi": 0.73}
    ],
    "Mg": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.57},
        {"oxidation_num": 2, "corr": 5, "radi": 0.66},
        {"oxidation_num": 2, "corr": 6, "radi": 0.72},
        {"oxidation_num": 2, "corr": 8, "radi": 0.89},
        {"oxidation_num": 3, "corr": 8, "radi": 0.40}
    ],
    "Rb": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.52},
        {"oxidation_num": 1, "corr": 7, "radi": 1.56},
        {"oxidation_num": 1, "corr": 8, "radi": 1.61},
        {"oxidation_num": 1, "corr": 9, "radi": 1.63},
        {"oxidation_num": 1, "corr": 10, "radi": 1.66},
        {"oxidation_num": 1, "corr": 11, "radi": 1.69},
        {"oxidation_num": 1, "corr": 12, "radi": 1.72},
        {"oxidation_num": 1, "corr": 14, "radi": 1.83}
    ],
    "Al": [
        {"oxidation_num": 3, "corr": 4, "radi": 0.39},
        {"oxidation_num": 3, "corr": 5, "radi": 0.48},
        {"oxidation_num": 3, "corr": 6, "radi": 0.535}
    ],
    "As": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.58},
        {"oxidation_num": 5, "corr": 4, "radi": 0.335},
        {"oxidation_num": 5, "corr": 6, "radi": 0.46}
    ],
    "Ga": [
        {"oxidation_num": 3, "corr": 4, "radi": 0.47},
        {"oxidation_num": 3, "corr": 5, "radi": 0.55},
        {"oxidation_num": 3, "corr": 6, "radi": 0.62}
    ],
    "Na": [
        {"oxidation_num": 1, "corr": 4, "radi": 0.99},
        {"oxidation_num": 1, "corr": 5, "radi": 1.00},
        {"oxidation_num": 1, "corr": 6, "radi": 1.02},
        {"oxidation_num": 1, "corr": 7, "radi": 1.12},
        {"oxidation_num": 1, "corr": 8, "radi": 1.18},
        {"oxidation_num": 1, "corr": 9, "radi": 1.24},
        {"oxidation_num": 1, "corr": 12, "radi": 1.39}
    ],
    "Ni": [
        {"oxidation_num": 2, "corr": 4, "radi": 0.55},
        {"oxidation_num": 2, "corr": 5, "radi": 0.63},
        {"oxidation_num": 2, "corr": 6, "radi": 0.69},
        {"oxidation_num": 3, "corr": 6, "radi": 0.56},
        {"oxidation_num": 3, "corr": 6, "radi": 0.60},
        {"oxidation_num": 4, "corr": 6, "radi": 0.48}
    ],
    "V": [
        {"oxidation_num": 2, "corr": 6, "radi": 0.79},
        {"oxidation_num": 3, "corr": 6, "radi": 0.64},
        {"oxidation_num": 4, "corr": 5, "radi": 0.53},
        {"oxidation_num": 4, "corr": 6, "radi": 0.58},
        {"oxidation_num": 4, "corr": 8, "radi": 0.72},
        {"oxidation_num": 5, "corr": 4, "radi": 0.355},
        {"oxidation_num": 5, "corr": 5, "radi": 0.46},
        {"oxidation_num": 5, "corr": 6, "radi": 0.54},
        {"oxidation_num": 6, "corr": 6, "radi": 0.38}
    ],
    "Yb": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.02},
        {"oxidation_num": 2, "corr": 7, "radi": 1.08},
        {"oxidation_num": 2, "corr": 8, "radi": 1.14},
        {"oxidation_num": 3, "corr": 6, "radi": 0.868},
        {"oxidation_num": 3, "corr": 7, "radi": 0.925},
        {"oxidation_num": 3, "corr": 8, "radi": 0.985},
        {"oxidation_num": 3, "corr": 9, "radi": 1.042}
    ],
    "Pt": [
        {"oxidation_num": 2, "corr": 6, "radi": 0.80},
        {"oxidation_num": 4, "corr": 6, "radi": 0.625},
        {"oxidation_num": 5, "corr": 6, "radi": 0.57}
    ],
    "Hf": [
        {"oxidation_num": 3, "corr": 4, "radi": 0.99},
        {"oxidation_num": 4, "corr": 4, "radi": 0.58},
        {"oxidation_num": 4, "corr": 6, "radi": 0.71},
        {"oxidation_num": 4, "corr": 7, "radi": 0.76},
        {"oxidation_num": 4, "corr": 8, "radi": 0.83}
    ],
    "W": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.96},
        {"oxidation_num": 4, "corr": 6, "radi": 0.66},
        {"oxidation_num": 5, "corr": 6, "radi": 0.62},
        {"oxidation_num": 6, "corr": 4, "radi": 0.42},
        {"oxidation_num": 6, "corr": 5, "radi": 0.51},
        {"oxidation_num": 6, "corr": 6, "radi": 0.60}
    ],
    "Nb": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.72},
        {"oxidation_num": 4, "corr": 6, "radi": 0.68},
        {"oxidation_num": 4, "corr": 8, "radi": 0.79},
        {"oxidation_num": 5, "corr": 4, "radi": 0.48},
        {"oxidation_num": 5, "corr": 6, "radi": 0.64},
        {"oxidation_num": 5, "corr": 7, "radi": 0.69},
        {"oxidation_num": 5, "corr": 8, "radi": 0.74}
    ],
    "Ta": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.72},
        {"oxidation_num": 4, "corr": 6, "radi": 0.68},
        {"oxidation_num": 5, "corr": 6, "radi": 0.64},
        {"oxidation_num": 5, "corr": 7, "radi": 0.69},
        {"oxidation_num": 5, "corr": 8, "radi": 0.74}
    ],
    "Re": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.96},
        {"oxidation_num": 4, "corr": 6, "radi": 0.63},
        {"oxidation_num": 5, "corr": 6, "radi": 0.58},
        {"oxidation_num": 6, "corr": 6, "radi": 0.55},
        {"oxidation_num": 7, "corr": 4, "radi": 0.38},
        {"oxidation_num": 7, "corr": 6, "radi": 0.53}
    ],
    "Zr": [
        {"oxidation_num": 3, "corr": 4, "radi": 0.99},
        {"oxidation_num": 4, "corr": 4, "radi": 0.59},
        {"oxidation_num": 4, "corr": 5, "radi": 0.66},
        {"oxidation_num": 4, "corr": 6, "radi": 0.72},
        {"oxidation_num": 4, "corr": 7, "radi": 0.78},
        {"oxidation_num": 4, "corr": 8, "radi": 0.84},
        {"oxidation_num": 4, "corr": 9, "radi": 0.89}
    ],
    "Te": [
        {"oxidation_num": -2, "corr": 6, "radi": 2.21},
        {"oxidation_num": 3, "corr": 3, "radi": 1.10},
        {"oxidation_num": 4, "corr": 3, "radi": 0.52},
        {"oxidation_num": 4, "corr": 4, "radi": 0.66},
        {"oxidation_num": 4, "corr": 6, "radi": 0.97},
        {"oxidation_num": 6, "corr": 4, "radi": 0.43},
        {"oxidation_num": 6, "corr": 6, "radi": 0.56}
    ],
    "Rh": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.665},
        {"oxidation_num": 4, "corr": 6, "radi": 0.60},
        {"oxidation_num": 5, "corr": 6, "radi": 0.55}
    ],
    "Sn": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.98},
        {"oxidation_num": 4, "corr": 4, "radi": 0.55},
        {"oxidation_num": 4, "corr": 5, "radi": 0.62},
        {"oxidation_num": 4, "corr": 6, "radi": 0.69},
        {"oxidation_num": 4, "corr": 7, "radi": 0.75},
        {"oxidation_num": 4, "corr": 8, "radi": 0.81}
    ],
    "Ru": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.68},
        {"oxidation_num": 4, "corr": 6, "radi": 0.62},
        {"oxidation_num": 5, "corr": 6, "radi": 0.565},
        {"oxidation_num": 7, "corr": 4, "radi": 0.38},
        {"oxidation_num": 8, "corr": 4, "radi": 0.36}
    ],
    "Ge": [
        {"oxidation_num": 2, "corr": 6, "radi": 0.73},
        {"oxidation_num": 4, "corr": 4, "radi": 0.39},
        {"oxidation_num": 4, "corr": 6, "radi": 0.53}
    ],
    "B": [
        {"oxidation_num": 3, "corr": 3, "radi": 0.01},
        {"oxidation_num": 3, "corr": 4, "radi": 0.11},
        {"oxidation_num": 3, "corr": 6, "radi": 0.27}
    ],
    "Be": [
        {"oxidation_num": 2, "corr": 3, "radi": 0.16},
        {"oxidation_num": 2, "corr": 4, "radi": 0.27},
        {"oxidation_num": 2, "corr": 6, "radi": 0.45}
    ],
    "Os": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.963},
        {"oxidation_num": 4, "corr": 6, "radi": 0.63},
        {"oxidation_num": 5, "corr": 6, "radi": 0.575},
        {"oxidation_num": 6, "corr": 5, "radi": 0.49},
        {"oxidation_num": 6, "corr": 6, "radi": 0.545},
        {"oxidation_num": 7, "corr": 6, "radi": 0.525},
        {"oxidation_num": 8, "corr": 4, "radi": 0.39}
    ],
    "Si": [
        {"oxidation_num": 3, "corr": 4, "radi": 0.66},
        {"oxidation_num": 4, "corr": 4, "radi": 0.26},
        {"oxidation_num": 4, "corr": 6, "radi": 0.40}
    ],
    "Ir": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.68},
        {"oxidation_num": 4, "corr": 6, "radi": 0.625},
        {"oxidation_num": 5, "corr": 6, "radi": 0.57},
        {"oxidation_num": 7, "corr": 6, "radi": 0.33}
    ],
    "Br": [
        {"oxidation_num": 1, "corr": 6, "radi": 1.96},
        {"oxidation_num": 3, "corr": 6, "radi": 1.10},
        {"oxidation_num": 5, "corr": 4, "radi": 0.75},
        {"oxidation_num": 7, "corr": 4, "radi": 0.25},
        {"oxidation_num": 7, "corr": 6, "radi": 0.39}
    ],
    "N": [
        {"oxidation_num": 3, "corr": 4, "radi": 1.46},
        {"oxidation_num": 3, "corr": 6, "radi": 0.16},
        {"oxidation_num": 5, "corr": 3, "radi": -0.104},
        {"oxidation_num": 5, "corr": 6, "radi": 0.13}
    ],
    "C": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.24},
        {"oxidation_num": 4, "corr": 3, "radi": -0.08},
        {"oxidation_num": 4, "corr": 4, "radi": 0.15},
        {"oxidation_num": 4, "corr": 6, "radi": 0.16}
    ],
    "Pu": [
        {"oxidation_num": 3, "corr": 6, "radi": 1.00},
        {"oxidation_num": 4, "corr": 6, "radi": 0.86},
        {"oxidation_num": 4, "corr": 8, "radi": 0.96},
        {"oxidation_num": 5, "corr": 6, "radi": 0.74},
        {"oxidation_num": 6, "corr": 6, "radi": 0.71}
    ],
    "Se": [
        {"oxidation_num": 2, "corr": 6, "radi": 1.98},
        {"oxidation_num": 3, "corr": 6, "radi": 0.99},
        {"oxidation_num": 4, "corr": 6, "radi": 0.50},
        {"oxidation_num": 6, "corr": 4, "radi": 0.28},
        {"oxidation_num": 6, "corr": 6, "radi": 0.42}
    ],
        "I": [
        {"oxidation_num": -1, "corr": 6, "radi": 2.20},
        {"oxidation_num": 5, "corr": 6, "radi": 0.95},
        {"oxidation_num": 7, "corr": 6, "radi": 0.53},

        {"oxidation_num": 7, "corr": 4, "radi": 0.42}
    ],
    "P": [
        {"oxidation_num": 3, "corr": 6, "radi": 0.44},
        {"oxidation_num": 5, "corr": 4, "radi": 0.17},
        {"oxidation_num": 5, "corr": 5, "radi": 0.29},
        {"oxidation_num": 5, "corr": 6, "radi": 0.38}
    ],
    "O": [
        {"oxidation_num": -2, "corr": 2, "radi": 1.35},
        {"oxidation_num": -2, "corr": 3, "radi": 1.36},
        {"oxidation_num": -2, "corr": 4, "radi": 1.38},
        {"oxidation_num": -2, "corr": 6, "radi": 1.40},
        {"oxidation_num": -2, "corr": 8, "radi": 1.42}
    ]
}

# %%
nan_elements = []
nan_oxidations = []

def add_selected_ionic_radii(df, ion_dict, op_corr):
    """
    Add new columns S_IR-A1, S_IR-A2, S_IR-B1, S_IR-B2 to df.
    Radius chosen based on oxidation number and coordination number (corr):
        - Prefer corr == 12 if available
        - Otherwise use the highest corr value
    """
    
    def get_radius(element, ox_state):
        """Return ionic radius for given element and oxidation state."""
        if pd.isna(element) or pd.isna(ox_state):
            return None
        element = str(element)
        try:
            ox_state = int(ox_state)
        except ValueError:
            return None
        
        if element not in ion_dict:
            if element not in nan_elements:
                nan_elements.append(element)

            return None
            
        # Filter by oxidation number
        data = [d for d in ion_dict[element] if d["oxidation_num"] == ox_state]
        if not data:
            temp = (element, ox_state)
            if temp not in nan_oxidations:
                nan_oxidations.append(temp)
            return None
        
        # Prefer corr == 12
        corr12 = [d for d in data if d["corr"] == op_corr]
        if corr12:
            return corr12[0]["radi"]
        
        # Else take the highest corr value
        best = max(data, key=lambda x: x["corr"])
        return best["radi"]
    
    # Create new columns for each site
    for site in ["A1", "A2", "B1", "B2"]:
        elem_col = site
        ox_col = f"{site}_OS"
        new_col = f"S_IR-{site}"
        df[new_col] = df.apply(lambda row: get_radius(row[elem_col], row[ox_col]), axis=1)
    
    return df

# %%
df_A1A2B2O6_c = add_selected_ionic_radii(df_A1A2B2O6, ionic_radii_database,op_corr=12)
df_A2B1B2O6_c = add_selected_ionic_radii(df_A2B1B2O6, ionic_radii_database,op_corr=12)
df_A1A2B1B2O6_c = add_selected_ionic_radii(df_A1A2B1B2O6, ionic_radii_database,op_corr=12)
df_ABO3_c = add_selected_ionic_radii(df_ABO3, ionic_radii_database,op_corr=6)
# Out:
# /var/folders/_d/wmmsrjw90wx28nd2_smrwgfr0000gn/T/ipykernel_96750/1645420668.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df.apply(lambda row: get_radius(row[elem_col], row[ox_col]), axis=1)
# /var/folders/_d/wmmsrjw90wx28nd2_smrwgfr0000gn/T/ipykernel_96750/1645420668.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df.apply(lambda row: get_radius(row[elem_col], row[ox_col]), axis=1)
# ...

# %%
print("Elements with missing ionic radii data:", nan_elements)
print("Element and oxidation numbers with missing ionic radii data:", nan_oxidations)
# Out:
# Elements with missing ionic radii data: []
# Element and oxidation numbers with missing ionic radii data: []

# %%
def save_nan_df(df , path):
       df.drop(columns=['X-A1', 'X-A2', 'X-B1', 'X-B2', 'I-A1', 'I-A2', 'I-B1', 'I-B2',
              'P-A1', 'P-A2', 'P-B1', 'P-B2', 'R-A1', 'R-A2', 'R-B1', 'R-B2', 'RA-A1',
              'RA-A2', 'RA-B1', 'RA-B2', 'H-A1', 'H-A2', 'H-B1', 'H-B2', 'L-A1',
              'L-A2', 'L-B1', 'L-B2', 'EA-A1', 'EA-A2', 'EA-B1', 'EA-B2', 'TC-A1',
              'TC-A2', 'TC-B1', 'TC-B2', 'TE-A1', 'TE-A2', 'TE-B1', 'TE-B2', 'EH-A1',
              'EH-A2', 'EH-B1', 'EH-B2', 'BE-A1', 'BE-A2', 'BE-B1', 'BE-B2',
              '3DOE-A1', '3DOE-A2', '3DOE-B1', '3DOE-B2', 'stable', 'Insulator',
              'PBE_bandgap', 'tolerance_factor', 'octahedral_factor', 'new_tau'])[df[["S_IR-A1", "S_IR-A2", "S_IR-B1", "S_IR-B2"]].isnull().any(axis=1)].to_csv(path, index=False)

# %%
save_nan_df(df_A1A2B2O6_c,path = "../data/nan_df/A1A2B2O6_missing_ionic_radii.csv")
save_nan_df(df_A2B1B2O6_c,path= "../data/nan_df/A2B1B2O6_missing_ionic_radii.csv")
save_nan_df(df_A1A2B1B2O6_c,path= "../data/nan_df/A1A2B1B2O6_missing_ionic_radii.csv")
save_nan_df(df_ABO3_c,path= "../data/nan_df/ABO3_missing_ionic_radii.csv")

# %%
def calculate_new_tau(df):
    R_O = 1.42  # Ionic radius of O^2- in pm
    tolerance_factor = ((df['S_IR-A1'] + df['S_IR-A2'])/2 + R_O) / (np.sqrt(2) * ((df['S_IR-B1'] + df['S_IR-B2'])/2 + R_O))
    df['tolerance_factor'] = tolerance_factor
    octahedral_factor = ((df['S_IR-B1'] + df['S_IR-B2'])/2) /  R_O
    df['octahedral_factor'] = octahedral_factor
    def calculate_new_tau_vectorized(df):
        rb = (df['S_IR-B1'] + df['S_IR-B2']) / 2
        ra = (df['S_IR-A1'] + df['S_IR-A2']) / 2
        rx = R_O
        na = df['A1_OS']

        invalid = (ra <= 0) | (rb <= 0) | (rx <= 0) | np.isclose(ra, rb)

        ratio = ra / rb
        with np.errstate(divide='ignore', invalid='ignore'):
            term1 = rx / rb
            term2 = na * (na - ratio / np.log(ratio))
            tau = term1 - term2


        tau[invalid] = np.nan
        return tau

    df['new_tau'] = calculate_new_tau_vectorized(df)
    return df

# %%
df_A1A2B2O6_c = calculate_new_tau(df_A1A2B2O6_c)
df_A2B1B2O6_c = calculate_new_tau(df_A2B1B2O6_c)
df_A1A2B1B2O6_c = calculate_new_tau(df_A1A2B1B2O6_c)
df_ABO3_c = calculate_new_tau(df_ABO3_c)
# Out:
# /var/folders/_d/wmmsrjw90wx28nd2_smrwgfr0000gn/T/ipykernel_96750/475570153.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tolerance_factor'] = tolerance_factor
# /var/folders/_d/wmmsrjw90wx28nd2_smrwgfr0000gn/T/ipykernel_96750/475570153.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['octahedral_factor'] = octahedral_factor
# /var/folders/_d/wmmsrjw90wx28nd2_smrwgfr0000gn/T/ipykernel_96750/475570153.py:25: SettingWithCopyWarning:
# ...

# %%
def filter(df_pred, lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18):
    df = df_pred[
        (df_pred['PBE_bandgap'] >= lower_bandgap) & (df_pred['PBE_bandgap'] <= upper_bandgap) &
        (df_pred['octahedral_factor'] >= octahedral_min) & (df_pred['octahedral_factor'] <= octahedral_max) &
        (df_pred['tolerance_factor'] >= tolerance_min) & (df_pred['tolerance_factor'] <= tolerance_max) &
        (df_pred['stable'] == 1) & (df_pred['Insulator'] == 1) &
        (df_pred['new_tau'] < new_tau_max)
    ]
    return df

# %%
print("Filtering candidates based on lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18 ")
filtered_ABO3 = filter(df_ABO3_c,lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18)
print(f"{len(filtered_ABO3)} candidates found for ABO3")
filtered_A2B1B2O6 = filter(df_A2B1B2O6_c,lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18)
print(f"{len(filtered_A2B1B2O6)} candidates found for A2B1B2O6" )
filtered_A1A2B2O6 = filter(df_A1A2B2O6_c,lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18)
print(f"{len(filtered_A1A2B2O6)} candidates found for A1A2B2O6")
filtered_A1A2B1B2O6 = filter(df_A1A2B1B2O6_c,lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18)
print(f"{len(filtered_A1A2B1B2O6)} candidates found for A1A2B1B2O6")
# Out:
# Filtering candidates based on lower_bandgap = 0.6, upper_bandgap = 3.0, octahedral_min=0.45, octahedral_max=0.9, tolerance_min=0.82, tolerance_max=1.08, new_tau_max=4.18
# 2 candidates found for ABO3
# 755 candidates found for A2B1B2O6
# 63 candidates found for A1A2B2O6
# 23812 candidates found for A1A2B1B2O6

# %%
def save_to_csv(df, filename):
    df = df.drop(columns=[ 'A1_OS', 'B1_OS',  'A2_OS','B2_OS',
        'X-A1', 'X-A2', 'X-B1', 'X-B2', 'I-A1', 'I-A2', 'I-B1', 'I-B2',
       'P-A1', 'P-A2', 'P-B1', 'P-B2', 'R-A1', 'R-A2', 'R-B1', 'R-B2', 'RA-A1',
       'RA-A2', 'RA-B1', 'RA-B2', 'H-A1', 'H-A2', 'H-B1', 'H-B2', 'L-A1',
       'L-A2', 'L-B1', 'L-B2', 'EA-A1', 'EA-A2', 'EA-B1', 'EA-B2', 'TC-A1',
       'TC-A2', 'TC-B1', 'TC-B2', 'TE-A1', 'TE-A2', 'TE-B1', 'TE-B2', 'EH-A1',
       'EH-A2', 'EH-B1', 'EH-B2', 'BE-A1', 'BE-A2', 'BE-B1', 'BE-B2',
       '3DOE-A1', '3DOE-A2', '3DOE-B1', '3DOE-B2', 'stable', 'Insulator',

        'new_tau'])
    df.to_csv(filename, index=False)

# %%
def save_to_csv(df, filename):
    df = df.drop(columns=[ 'A1_OS', 'B1_OS',  'A2_OS','B2_OS',
        'X-A1', 'X-A2', 'X-B1', 'X-B2', 'I-A1', 'I-A2', 'I-B1', 'I-B2',
       'P-A1', 'P-A2', 'P-B1', 'P-B2', 'R-A1', 'R-A2', 'R-B1', 'R-B2', 'RA-A1',
       'RA-A2', 'RA-B1', 'RA-B2', 'H-A1', 'H-A2', 'H-B1', 'H-B2', 'L-A1',
       'L-A2', 'L-B1', 'L-B2', 'EA-A1', 'EA-A2', 'EA-B1', 'EA-B2', 'TC-A1',
       'TC-A2', 'TC-B1', 'TC-B2', 'TE-A1', 'TE-A2', 'TE-B1', 'TE-B2', 'EH-A1',
       'EH-A2', 'EH-B1', 'EH-B2', 'BE-A1', 'BE-A2', 'BE-B1', 'BE-B2',
       '3DOE-A1', '3DOE-A2', '3DOE-B1', '3DOE-B2', 'stable', 'Insulator'])
    df.to_csv(filename, index=False)

# %%
save_to_csv(df_ABO3, "../data/result/ABO3_stable_insulator.csv")

# %%
save_to_csv(filtered_ABO3, '../data/result/filtered_ABO3.csv')
save_to_csv(filtered_A2B1B2O6, '../data/result/filtered_A2B1B2O6.csv')
save_to_csv(filtered_A1A2B2O6, '../data/result/filtered_A1A2B2O6.csv')
save_to_csv(filtered_A1A2B1B2O6, '../data/result/filtered_A1A2B1B2O6.csv')
